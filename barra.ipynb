# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
from barra import BarraModel

# %%
barra1 = BarraModel(20, 1000, 10, 20)
barra1.generate_data(12345, 34567, 56789, 78901)
barra1.calculate()

# %%
barra1.show_factor_ret('style')
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       F01            20           1.12686        0.45958        0.91737
#       F02            20           0.42896        0.21510        0.31893
#       F03            20          -0.74044       -0.30109       -0.92081
#       F04            20          -0.00626       -0.00357       -0.03892
#       F05            20           0.11432        0.07018       -0.02369
#       F06            20          -0.30201       -0.16907       -0.52571
#       F07            20           0.03270        0.02022       -0.07038
#       F08            20           0.14477        0.07287        0.18136
#       F09            20          -0.43677       -0.26718       -0.89362
#       F10            20          -0.54602       -0.29042       -0.86229

# %%
barra1.show_factor_ret('industry', 2)
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I01            20           2.22498        0.34183        0.89819
#       I02            20          -0.66171       -0.09301       -0.47041
#       I03            20           0.45905        0.07326       -0.04787
#       I04            20           0.81048        0.11308        0.25570
#       I05            20          -0.22703       -0.02216        0.25797
#       I06            20           1.32649        0.16937        0.74771
#       I07            20           2.29983        0.26004        0.82536
#       I08            20           0.01948        0.00254        0.15279
#       I09            20          -0.97223       -0.14457       -0.80572
#       I10            20          -1.96377       -0.32902       -0.89371
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I11            20           4.82068        0.68244        0.94791
# ...

# %%
barra1.decomposition()
barra1.show_factor_ret('portfolio', 3)
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       F01            19          -0.00976       -0.04545       -0.15176
#       F02            19          -0.03304       -0.24227       -0.52352
#       F03            19           0.01156        0.04007        0.59708
#       F04            19          -0.01480       -0.08491       -0.80015
#       F05            19          -0.01269       -0.15861       -0.83965
#       F06            19          -0.01487       -0.12680       -0.71327
#       F07            19           0.01176        0.12859        0.68329
#       F08            19           0.01946        0.10758        0.28206
#       F09            19           0.00396        0.03506        0.22649
#       F10            19          -0.02393       -0.16403       -0.78988
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I01            19          -0.03736       -0.44466       -0.90838
# ...

# %%
barra1.generate_data(12, 34, 56, 78)
barra1.calculate('Dump_D2')
barra1.show_factor_ret('style', 1, 'Dump_D2/')
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       F01            20           0.26907        0.16428        0.60925
#       F02            20          -0.22221       -0.10705       -0.79026
#       F03            20           0.15441        0.10225        0.63164
#       F04            20          -0.20388       -0.08331       -0.71808
#       F05            20          -0.01615       -0.00837        0.43084
#       F06            20          -0.10204       -0.05613        0.00840
#       F07            20          -0.13266       -0.08399       -0.66061
#       F08            20          -0.59586       -0.36001       -0.87412
#       F09            20          -0.68368       -0.38008       -0.83630
#       F10            20           0.15691        0.10294        0.41045

# %%
barra1.show_factor_ret('industry', 2, 'Dump_D2/')
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I01            20          -2.57765       -0.34330       -0.93705
#       I02            20           2.24979        0.30325        0.87719
#       I03            20           2.73461        0.37238        0.83888
#       I04            20          -0.04342       -0.00481        0.52132
#       I05            20          -2.39331       -0.41927       -0.94994
#       I06            20           1.19086        0.15501        0.81852
#       I07            20          -0.73725       -0.07518       -0.78272
#       I08            20           1.38536        0.21728        0.88730
#       I09            20          -1.75484       -0.25727       -0.86505
#       I10            20           2.28089        0.28993        0.84859
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I11            20           0.12890        0.02250        0.29358
# ...

# %%
barra2 = BarraModel(200, 3000, 10, 20)
barra2.run_model(123, 345, 567, 789)
# Out:
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       F01            200         -0.02363       -0.01977        0.76646
#       F02            200         -0.02527       -0.02519       -0.55642
#       F03            200          0.00930        0.00838       -0.02464
#       F04            200         -0.07809       -0.07532       -0.80130
#       F05            200         -0.14795       -0.12734       -0.93495
#       F06            200         -0.00637       -0.00566        0.13405
#       F07            200          0.06742        0.06531        0.85965
#       F08            200          0.05638        0.05569        0.71692
#       F09            200          0.09381        0.07932        0.90773
#       F10            200         -0.04333       -0.04244       -0.77187
#     Factor          Days           Mean        Mean / Std     AutoTsCorr
#       I01            200         -0.62962       -0.12108       -0.94173
# ...
